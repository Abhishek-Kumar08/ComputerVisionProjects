# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.4/40.4 kB 1.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 715.1/715.1 kB 26.5 MB/s eta 0:00:00
# ...

# %% [markdown]
# Dataset: https://www.kaggle.com/datasets/kratos08/licenceplate-dataset/data

# %%
import os
from ultralytics import YOLO

# %%
f = '/kaggle/input/licenceplate-dataset/data'

# %%
model = YOLO('yolov8n.yaml')
results = model.train(data=os.path.join(f,'config.yaml'), epochs=50)
# Out:
# Ultralytics YOLOv8.1.15 🚀 Python-3.10.13 torch-2.1.2 CUDA:0 (Tesla P100-PCIE-16GB, 16276MiB)
# ...
